# %%
import numpy as np
import tensorflow as tf
import os
import copy
from math import pi

from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
folder_path = '/Users/joonghocho/Radar/Intelligent_Radar/gui/service_modules/data/train/'
file_list = os.listdir(folder_path)
print(file_list)
# Out:
# ['paper', 'can', 'glass', 'plastic']

# %%
def readNpy(dir_path):
    Can = list()
    Paper = list()
    Plastic = list()
    Glass = list()
    for dir in os.listdir(dir_path):
        d_path = os.path.join(dir_path, dir)
        file_list = os.listdir(d_path)
        for file in file_list:
            file_path = os.path.join(d_path, file)
            if dir == 'can':
                if len(Can) == 0:
                    Can = np.load(file_path)
                else :
                    Can = np.append(Can, np.load(file_path), axis = 0)
            elif dir == 'paper':
                if len(Paper) == 0:
                    Paper = np.load(file_path)
                else :
                    Paper = np.append(Paper, np.load(file_path), axis = 0)
            elif dir == 'glass':
                if len(Glass) == 0:
                    Glass = np.load(file_path)
                else:
                    Glass = np.append(Glass, np.load(file_path), axis = 0)
            elif dir == 'plastic':
                if len(Plastic) == 0:
                    Plastic = np.load(file_path)
                else:
                    Plastic = np.append(Plastic, np.load(file_path), axis = 0)

    return Can, Paper, Glass, Plastic

# %%
Can, Paper, Glass, Plastic = readNpy(folder_path)

# %%
x = np.linspace(10,18,167)

# %%
def data_plot(array,file):
    x = np.linspace(13,18,array.shape[1])
    for j in range(len(array)):
        plt.subplot(2, 1, 1)
        plt.title(file)
        plt.plot(x ,np.abs(array[j]))
        plt.subplot(2, 1, 2)
        plt.plot(x, (np.angle(array[j])+1)/2)
    plt.show()

# %%
for dir in os.listdir(folder_path):
    d_path = os.path.join(folder_path, dir)
    file_list = os.listdir(d_path)
    subplot_len = len(file_list)
    subplot_pos = 0
    for file in file_list:
        print(file)
        file_path = os.path.join(d_path, file)
        data = np.load(file_path)
        data_plot(data, file)
# Out:
# paper9.npy
# paper8.npy
# paper5.npy
# paper4.npy
# paper6.npy
# paper7.npy
# paper3.npy
# paper2.npy
# paper1.npy
# can7.npy
# can6.npy
# can4.npy
# can5.npy
# can1.npy
# can2.npy
# can3.npy
# glass2.npy
# glass3.npy
# glass1.npy
# glass4.npy
# glass5.npy
# glass7.npy
# glass6.npy
# plastic1.npy
# plastic3.npy
# plastic2.npy
# plastic6.npy
# plastic7.npy
# plastic5.npy
# plastic4.npy
# plastic9.npy
# plastic8.npy
# plastic12.npy
# plastic13.npy
# plastic11.npy
# plastic10.npy

# %%
arr = list()
arr = np.array(arr)

# %%
for file in file_list:
    if len(arr) == 0:
        arr = np.load(os.path.join(folder_path, file))
    else:
        arr = np.concatenate((arr, np.load(os.path.join(folder_path, file))), axis=0)

# %%
arr_amp = np.abs(arr)
arr_phs = np.angle(arr)
arr_sin = np.sin(arr_phs)
data_plot(arr_amp, arr_sin)

# %%
x = np.linspace(10, 20, 208)

# %%
plt.rcParams["figure.figsize"] = (20,40)

# %%
print(type(file))
# Out:
# <class 'str'>

# %%
a = 1
for file in file_list:
    arr = np.load(os.path.join(folder_path, file))
    arr_amp = np.abs(arr)
    arr_phs = np.angle(arr)
    arr_sin = np.sin(arr_phs)
    for i in range(arr_amp.shape[0]):
        plt.subplot(18, 1, a)
        plt.plot(x, arr_amp[i])
        plt.title(file + ' amp')
        plt.subplot(18, 1, a+1)
        plt.plot(x, arr_sin[i])
        plt.title(file + ' sin')
    a = a + 2
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def sep_data_plot(data_amp, data_phs):
    x = np.linspace(10,20,208)
    for i in range(data_amp.shape[0]):
        plt.subplot(data_amp.shape[0], 1, 1)
        plt.plot(x, data_amp[i])
        plt.subplot(2, 1, 2)
        plt.plot(x, data_phs[i])
    plt.show()
