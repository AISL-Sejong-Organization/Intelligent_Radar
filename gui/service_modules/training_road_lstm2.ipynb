# %%
import numpy as np
import tensorflow as tf
import os
import copy
from math import pi
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import seaborn as sns
from pandas import DataFrame as DF
from models import AP_ResNet, ResNet, VGG_branch, ResNetLSTM, ConvLSTM, build_transformer_model

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
from classifier import preprocessing as prep
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
# Out:
# 2022-08-16 03:32:29.478311: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
class_names = ['asphalt','bicycle','block','floor','ground']
bound = 414
data_len = 414
use_len = 100

# %%
def heatmap(matrix,title):
    df=DF(matrix, index = class_names, columns = class_names)
    plt.figure(figsize=(10,10))
    sns.heatmap(df, annot=True)
    plt.tick_params(axis='x', top=True, labeltop = True,bottom=False, labelbottom=False)
    plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
    plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
    plt.xlabel("Prediction",position = (0.5,1.0+0.05))
    plt.ylabel("Object")
    plt.title(title)

# %%
label2idx_Dict = {
                'asphalt' : 0,
                'bicycle' : 1,
                'block' : 2,
                'floor' : 3,
                'ground' : 4,
            }

idx2label_Dict = {
    0 : 'asphalt',
    1 : 'bicycle',
    2 : 'block',
    3 : 'floor',
    4 : 'ground',
}

# %%
dir_path = './road_data'
def readNpy(dir_path):
    class_num = len(idx2label_Dict)

    Asphalt = list()
    Bicycle = list()
    Block = list()
    Floor = list()
    Ground = list()
    Asphalt = np.array(Asphalt)
    Bicycle = np.array(Bicycle)
    Block = np.array(Block)
    Floor = np.array(Floor)
    Ground = np.array(Ground)
    

    for dir in os.listdir(dir_path):
        d_path = os.path.join(dir_path, dir)
        file_list = os.listdir(d_path)
        for file in file_list:
            file_path = os.path.join(d_path, file)
            if dir == idx2label_Dict[0] :
                if len(Asphalt) == 0:
                    Asphalt = np.load(file_path, allow_pickle=True)
                else :
                    Asphalt = np.append(Asphalt, np.load(file_path), axis = 0)
            elif dir == idx2label_Dict[1]:
                if len(Bicycle) == 0:
                    Bicycle = np.load(file_path, allow_pickle=True)
                else :
                    Bicycle = np.append(Bicycle, np.load(file_path), axis = 0)
            elif dir == idx2label_Dict[2]:
                if len(Block) == 0:
                    Block = np.load(file_path, allow_pickle=True)
                else:
                    Block = np.append(Block, np.load(file_path), axis = 0)
            elif dir == idx2label_Dict[3]:
                if len(Floor) == 0:
                    Floor = np.load(file_path, allow_pickle=True)
                else:
                    Floor = np.append(Floor, np.load(file_path), axis = 0)
            elif dir == idx2label_Dict[4]:
                if len(Ground) == 0:
                    Ground = np.load(file_path, allow_pickle=True)
                else:
                    Ground = np.append(Ground, np.load(file_path), axis = 0)

    # bound = Asphalt.shape[1]
    global use_len
    global data_len

    Ground_label = np.full((Ground.shape[0], class_num), np.eye(len(label2idx_Dict))[label2idx_Dict['ground']])
    Asphalt_label = np.full((Asphalt.shape[0],class_num), np.eye(len(label2idx_Dict))[label2idx_Dict['asphalt']])
    Bicycle_label = np.full((Bicycle.shape[0],class_num), np.eye(len(label2idx_Dict))[label2idx_Dict['bicycle']])
    Block_label = np.full((Block.shape[0],class_num), np.eye(len(label2idx_Dict))[label2idx_Dict['block']])
    Floor_label = np.full((Floor.shape[0],class_num), np.eye(len(label2idx_Dict))[label2idx_Dict['floor']])

    Ground = np.concatenate((Ground, Ground_label), axis=1)
    Asphalt = np.concatenate((Asphalt, Asphalt_label), axis=1)
    Bicycle = np.concatenate((Bicycle, Bicycle_label), axis=1)
    Block = np.concatenate((Block, Block_label), axis=1)
    Floor = np.concatenate((Floor, Floor_label), axis=1)
    
    array = Asphalt
    array = np.append(array, Bicycle, axis = 0)
    array = np.append(array, Block, axis = 0)
    array = np.append(array, Floor, axis = 0)
    array = np.append(array, Ground, axis = 0)
    s = np.arange(array.shape[0])
    np.random.shuffle(s)
    array_s = array[s]

    X = array_s[:,:use_len]
    Y = np.real(array_s[:,data_len:])
    return copy.deepcopy(X), copy.deepcopy(Y)

X, y = readNpy(dir_path)

# %%
def seperater(arr):
    # global maximum
    pre_data = arr
    amp = np.abs(pre_data)
    # amp = amp / maximum
    phs = np.angle(pre_data)
    # phs = (phs - (- pi)) / (pi - (- pi))
    sin = np.sin(phs)
    sin = (sin + 1) / 2
    seperated_data = np.stack((amp.T,sin.T), axis=0)
    seperated_data = np.expand_dims(seperated_data, axis=0)
    return np.array(seperated_data)

# %%
def dataSeperator(arr):
    temp = copy.deepcopy(seperater(arr[0]))
    for i in range(1, len(arr)):
        temp = np.concatenate((temp, seperater(arr[i])), axis=0)
    return temp

# %%
# Split_X = dataSeperator(X)

# %%
Split_X = np.abs(X)

# %%
checkpoint_filepath = 'road_detection_lstm'
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = './model/' + checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only = True,
    save_weigths_only = False,
)
log_dir = './logs/fit/'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

# %%
def create_sequences(data, seq_length):
    xs = []
    ys = []
    for i in range(len(data[0])-seq_length-1):
        x = data[0][:][i:(i+seq_length)]
        y = data[1][i+seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

# %%
from sklearn.preprocessing import normalize

Split_X = normalize(Split_X)

# %%
seq_length = 30
X, Y = create_sequences((Split_X, y), seq_length = seq_length)

# %%
print(X.shape, Y.shape)
# Out:
# (2369, 30, 100) (2369, 5)

# %%
def train(
    model, X, Y,
    test_X, test_Y, 
    batch_size = 64, history_dict = None
    ):
    Epoch = 1
    callback = tf.keras.callbacks.ModelCheckpoint(
        filepath = './model/' + 'Resnet_LSTM',
        monitor='val_accuracy',
        mode='max',
        save_best_only = True,
        save_weigths_only = False,
    )
    optimizer = tf.keras.optimizers.Adam()
    loss = tf.keras.losses.CategoricalCrossentropy()
    model.compile(optimizer = optimizer , loss = loss, 
                metrics = ['accuracy', 'categorical_crossentropy'])
    history = model.fit(X, Y,  batch_size = batch_size, epochs = Epoch,
                callbacks = callback, 
                validation_data = (test_X, test_Y),
                # validation_split = 0.3
                )
    return history

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 42)

# %%
input_shape = X_train.shape[1:]
model = build_transformer_model(
    input_shape,
    head_size=256,
    num_heads=32,
    ff_dim=64,
    num_transformer_blocks=4,
    mlp_units=[2048],
    mlp_dropout=0.8,
    dropout=0.8,
)
# Out:
# 2022-08-16 03:32:36.182968: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-16 03:32:36.814397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22304 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:af:00.0, compute capability: 8.6

# %%
loss = tf.keras.losses.CategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
model.compile(optimizer = optimizer , loss = loss, 
            metrics = ['accuracy', 'categorical_crossentropy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30, 100)]    0           []
#
#  layer_normalization (LayerNorm  (None, 30, 100)     200         ['input_1[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 30, 100)     3301476     ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  dropout (Dropout)              (None, 30, 100)      0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 30, 100)     0           ['dropout[0][0]',
#  da)                                                              'input_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 30, 100)     200         ['tf.__operators__.add[0][0]']
#  rmalization)
#
#  conv1d (Conv1D)                (None, 30, 64)       6464        ['layer_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 30, 64)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 30, 100)      6500        ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 30, 100)     0           ['conv1d_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 30, 100)     200         ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 30, 100)     3301476     ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 30, 100)      0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 30, 100)     0           ['dropout_2[0][0]',
#  mbda)                                                            'tf.__operators__.add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 30, 100)     200         ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  conv1d_2 (Conv1D)              (None, 30, 64)       6464        ['layer_normalization_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 30, 64)       0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 30, 100)      6500        ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 30, 100)     0           ['conv1d_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 30, 100)     200         ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 30, 100)     3301476     ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 30, 100)      0           ['multi_head_attention_2[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 30, 100)     0           ['dropout_4[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 30, 100)     200         ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  conv1d_4 (Conv1D)              (None, 30, 64)       6464        ['layer_normalization_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 30, 64)       0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 30, 100)      6500        ['dropout_5[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 30, 100)     0           ['conv1d_5[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 30, 100)     200         ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 30, 100)     3301476     ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  dropout_6 (Dropout)            (None, 30, 100)      0           ['multi_head_attention_3[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 30, 100)     0           ['dropout_6[0][0]',
#  mbda)                                                            'tf.__operators__.add_5[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 30, 100)     200         ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  conv1d_6 (Conv1D)              (None, 30, 64)       6464        ['layer_normalization_7[0][0]']
#
#  dropout_7 (Dropout)            (None, 30, 64)       0           ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 30, 100)      6500        ['dropout_7[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 30, 100)     0           ['conv1d_7[0][0]',
#  mbda)                                                            'tf.__operators__.add_6[0][0]']
#
#  global_average_pooling1d (Glob  (None, 30)          0           ['tf.__operators__.add_7[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 2048)         63488       ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_8 (Dropout)            (None, 2048)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 5)            10245       ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 13,333,093
# Trainable params: 13,333,093
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(
    X_train,
    Y_train,
    # validation_split=0.2,
    epochs=2000,
    batch_size=64,
    # callbacks=callbacks,
    validation_data=(X_test,Y_test),
)
# Out:
# Epoch 1/2000
# 2022-08-16 03:32:41.948086: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-08-16 03:32:42.128926: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8301
# 26/26 [==============================] - 8s 70ms/step - loss: 1.6158 - accuracy: 0.1815 - categorical_crossentropy: 1.6158 - val_loss: 1.5878 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5878
# Epoch 2/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5896 - accuracy: 0.2407 - categorical_crossentropy: 1.5896 - val_loss: 1.6018 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.6018
# Epoch 3/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 1.5713 - accuracy: 0.2636 - categorical_crossentropy: 1.5713 - val_loss: 1.5826 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5826
# Epoch 4/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5685 - accuracy: 0.2618 - categorical_crossentropy: 1.5685 - val_loss: 1.5799 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5799
# Epoch 5/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5699 - accuracy: 0.2497 - categorical_crossentropy: 1.5699 - val_loss: 1.5957 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5957
# Epoch 6/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5669 - accuracy: 0.2606 - categorical_crossentropy: 1.5669 - val_loss: 1.6168 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.6168
# Epoch 7/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5776 - accuracy: 0.2364 - categorical_crossentropy: 1.5776 - val_loss: 1.6250 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.6250
# Epoch 8/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5729 - accuracy: 0.2413 - categorical_crossentropy: 1.5729 - val_loss: 1.5954 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5954
# Epoch 9/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5656 - accuracy: 0.2437 - categorical_crossentropy: 1.5656 - val_loss: 1.5837 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5837
# Epoch 10/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5647 - accuracy: 0.2630 - categorical_crossentropy: 1.5647 - val_loss: 1.5704 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5704
# Epoch 11/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5682 - accuracy: 0.2413 - categorical_crossentropy: 1.5682 - val_loss: 1.5735 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5735
# Epoch 12/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5628 - accuracy: 0.2624 - categorical_crossentropy: 1.5628 - val_loss: 1.5717 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5717
# Epoch 13/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5643 - accuracy: 0.2587 - categorical_crossentropy: 1.5643 - val_loss: 1.6665 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.6665
# Epoch 14/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5737 - accuracy: 0.2358 - categorical_crossentropy: 1.5737 - val_loss: 1.6312 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.6312
# Epoch 15/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5682 - accuracy: 0.2612 - categorical_crossentropy: 1.5682 - val_loss: 1.6178 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.6178
# Epoch 16/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5650 - accuracy: 0.2479 - categorical_crossentropy: 1.5650 - val_loss: 1.5866 - val_accuracy: 0.2082 - val_categorical_crossentropy: 1.5866
# Epoch 17/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5624 - accuracy: 0.2654 - categorical_crossentropy: 1.5624 - val_loss: 1.5728 - val_accuracy: 0.2082 - val_categorical_crossentropy: 1.5728
# Epoch 18/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5642 - accuracy: 0.2581 - categorical_crossentropy: 1.5642 - val_loss: 1.5757 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5757
# Epoch 19/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5633 - accuracy: 0.2612 - categorical_crossentropy: 1.5633 - val_loss: 1.5798 - val_accuracy: 0.2082 - val_categorical_crossentropy: 1.5798
# Epoch 20/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5629 - accuracy: 0.2539 - categorical_crossentropy: 1.5629 - val_loss: 1.5832 - val_accuracy: 0.2138 - val_categorical_crossentropy: 1.5832
# Epoch 21/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5559 - accuracy: 0.2744 - categorical_crossentropy: 1.5559 - val_loss: 1.5779 - val_accuracy: 0.2096 - val_categorical_crossentropy: 1.5779
# Epoch 22/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5620 - accuracy: 0.2600 - categorical_crossentropy: 1.5620 - val_loss: 1.5806 - val_accuracy: 0.2025 - val_categorical_crossentropy: 1.5806
# Epoch 23/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5661 - accuracy: 0.2521 - categorical_crossentropy: 1.5661 - val_loss: 1.5765 - val_accuracy: 0.2053 - val_categorical_crossentropy: 1.5765
# Epoch 24/2000
# 26/26 [==============================] - 1s 52ms/step - loss: 1.5584 - accuracy: 0.2473 - categorical_crossentropy: 1.5584 - val_loss: 1.5738 - val_accuracy: 0.2068 - val_categorical_crossentropy: 1.5738
# Epoch 25/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5616 - accuracy: 0.2563 - categorical_crossentropy: 1.5616 - val_loss: 1.5743 - val_accuracy: 0.2082 - val_categorical_crossentropy: 1.5743
# Epoch 26/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5644 - accuracy: 0.2533 - categorical_crossentropy: 1.5644 - val_loss: 1.5727 - val_accuracy: 0.2068 - val_categorical_crossentropy: 1.5727
# Epoch 27/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5631 - accuracy: 0.2708 - categorical_crossentropy: 1.5631 - val_loss: 1.5724 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5724
# Epoch 28/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5557 - accuracy: 0.2786 - categorical_crossentropy: 1.5557 - val_loss: 1.5798 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5798
# Epoch 29/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5593 - accuracy: 0.2581 - categorical_crossentropy: 1.5593 - val_loss: 1.5714 - val_accuracy: 0.2152 - val_categorical_crossentropy: 1.5714
# Epoch 30/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5579 - accuracy: 0.2551 - categorical_crossentropy: 1.5579 - val_loss: 1.5744 - val_accuracy: 0.2025 - val_categorical_crossentropy: 1.5744
# Epoch 31/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5612 - accuracy: 0.2714 - categorical_crossentropy: 1.5612 - val_loss: 1.5800 - val_accuracy: 0.2082 - val_categorical_crossentropy: 1.5800
# Epoch 32/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5612 - accuracy: 0.2666 - categorical_crossentropy: 1.5612 - val_loss: 1.5807 - val_accuracy: 0.2096 - val_categorical_crossentropy: 1.5807
# Epoch 33/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5630 - accuracy: 0.2449 - categorical_crossentropy: 1.5630 - val_loss: 1.5809 - val_accuracy: 0.2096 - val_categorical_crossentropy: 1.5809
# Epoch 34/2000
# 26/26 [==============================] - 1s 52ms/step - loss: 1.5629 - accuracy: 0.2461 - categorical_crossentropy: 1.5629 - val_loss: 1.5768 - val_accuracy: 0.2068 - val_categorical_crossentropy: 1.5768
# Epoch 35/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5589 - accuracy: 0.2497 - categorical_crossentropy: 1.5589 - val_loss: 1.5789 - val_accuracy: 0.2124 - val_categorical_crossentropy: 1.5789
# Epoch 36/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5610 - accuracy: 0.2636 - categorical_crossentropy: 1.5610 - val_loss: 1.5773 - val_accuracy: 0.2053 - val_categorical_crossentropy: 1.5773
# Epoch 37/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5606 - accuracy: 0.2618 - categorical_crossentropy: 1.5606 - val_loss: 1.5780 - val_accuracy: 0.2096 - val_categorical_crossentropy: 1.5780
# Epoch 38/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 1.5653 - accuracy: 0.2382 - categorical_crossentropy: 1.5653 - val_loss: 1.5825 - val_accuracy: 0.1997 - val_categorical_crossentropy: 1.5825
# Epoch 39/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5597 - accuracy: 0.2756 - categorical_crossentropy: 1.5597 - val_loss: 1.5803 - val_accuracy: 0.2124 - val_categorical_crossentropy: 1.5803
# Epoch 40/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5563 - accuracy: 0.2720 - categorical_crossentropy: 1.5563 - val_loss: 1.5803 - val_accuracy: 0.2053 - val_categorical_crossentropy: 1.5803
# Epoch 41/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5563 - accuracy: 0.2726 - categorical_crossentropy: 1.5563 - val_loss: 1.5811 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5811
# Epoch 42/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5567 - accuracy: 0.2708 - categorical_crossentropy: 1.5567 - val_loss: 1.5823 - val_accuracy: 0.2124 - val_categorical_crossentropy: 1.5823
# Epoch 43/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5554 - accuracy: 0.2708 - categorical_crossentropy: 1.5554 - val_loss: 1.5818 - val_accuracy: 0.1997 - val_categorical_crossentropy: 1.5818
# Epoch 44/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5554 - accuracy: 0.2612 - categorical_crossentropy: 1.5554 - val_loss: 1.5804 - val_accuracy: 0.2053 - val_categorical_crossentropy: 1.5804
# Epoch 45/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5512 - accuracy: 0.2883 - categorical_crossentropy: 1.5512 - val_loss: 1.5772 - val_accuracy: 0.2138 - val_categorical_crossentropy: 1.5772
# Epoch 46/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5592 - accuracy: 0.2636 - categorical_crossentropy: 1.5592 - val_loss: 1.5766 - val_accuracy: 0.2053 - val_categorical_crossentropy: 1.5766
# Epoch 47/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5550 - accuracy: 0.2865 - categorical_crossentropy: 1.5550 - val_loss: 1.5847 - val_accuracy: 0.2053 - val_categorical_crossentropy: 1.5847
# Epoch 48/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5554 - accuracy: 0.2805 - categorical_crossentropy: 1.5554 - val_loss: 1.5882 - val_accuracy: 0.2039 - val_categorical_crossentropy: 1.5882
# Epoch 49/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5548 - accuracy: 0.2672 - categorical_crossentropy: 1.5548 - val_loss: 1.5843 - val_accuracy: 0.2166 - val_categorical_crossentropy: 1.5843
# Epoch 50/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5583 - accuracy: 0.2762 - categorical_crossentropy: 1.5583 - val_loss: 1.5950 - val_accuracy: 0.2082 - val_categorical_crossentropy: 1.5950
# Epoch 51/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5545 - accuracy: 0.2684 - categorical_crossentropy: 1.5545 - val_loss: 1.6116 - val_accuracy: 0.1969 - val_categorical_crossentropy: 1.6116
# Epoch 52/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5469 - accuracy: 0.2817 - categorical_crossentropy: 1.5469 - val_loss: 1.5870 - val_accuracy: 0.2124 - val_categorical_crossentropy: 1.5870
# Epoch 53/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5562 - accuracy: 0.2654 - categorical_crossentropy: 1.5562 - val_loss: 1.6237 - val_accuracy: 0.1941 - val_categorical_crossentropy: 1.6237
# Epoch 54/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5514 - accuracy: 0.2793 - categorical_crossentropy: 1.5514 - val_loss: 1.5885 - val_accuracy: 0.2180 - val_categorical_crossentropy: 1.5885
# Epoch 55/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5477 - accuracy: 0.2811 - categorical_crossentropy: 1.5477 - val_loss: 1.6028 - val_accuracy: 0.2096 - val_categorical_crossentropy: 1.6028
# Epoch 56/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5497 - accuracy: 0.2823 - categorical_crossentropy: 1.5497 - val_loss: 1.5851 - val_accuracy: 0.2180 - val_categorical_crossentropy: 1.5851
# Epoch 57/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5456 - accuracy: 0.3028 - categorical_crossentropy: 1.5456 - val_loss: 1.5920 - val_accuracy: 0.2180 - val_categorical_crossentropy: 1.5920
# Epoch 58/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5475 - accuracy: 0.2895 - categorical_crossentropy: 1.5475 - val_loss: 1.5875 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.5875
# Epoch 59/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5405 - accuracy: 0.2835 - categorical_crossentropy: 1.5405 - val_loss: 1.5952 - val_accuracy: 0.2222 - val_categorical_crossentropy: 1.5952
# Epoch 60/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5429 - accuracy: 0.2835 - categorical_crossentropy: 1.5429 - val_loss: 1.5986 - val_accuracy: 0.2096 - val_categorical_crossentropy: 1.5986
# Epoch 61/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5419 - accuracy: 0.2835 - categorical_crossentropy: 1.5419 - val_loss: 1.5949 - val_accuracy: 0.2138 - val_categorical_crossentropy: 1.5949
# Epoch 62/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5415 - accuracy: 0.2889 - categorical_crossentropy: 1.5415 - val_loss: 1.5901 - val_accuracy: 0.2152 - val_categorical_crossentropy: 1.5901
# Epoch 63/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5343 - accuracy: 0.2961 - categorical_crossentropy: 1.5343 - val_loss: 1.5999 - val_accuracy: 0.2208 - val_categorical_crossentropy: 1.5999
# Epoch 64/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5397 - accuracy: 0.2925 - categorical_crossentropy: 1.5397 - val_loss: 1.6031 - val_accuracy: 0.2152 - val_categorical_crossentropy: 1.6031
# Epoch 65/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5406 - accuracy: 0.2786 - categorical_crossentropy: 1.5406 - val_loss: 1.6080 - val_accuracy: 0.2264 - val_categorical_crossentropy: 1.6080
# Epoch 66/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5410 - accuracy: 0.2750 - categorical_crossentropy: 1.5410 - val_loss: 1.6233 - val_accuracy: 0.2082 - val_categorical_crossentropy: 1.6233
# Epoch 67/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5402 - accuracy: 0.2720 - categorical_crossentropy: 1.5402 - val_loss: 1.6061 - val_accuracy: 0.2180 - val_categorical_crossentropy: 1.6061
# Epoch 68/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5334 - accuracy: 0.2925 - categorical_crossentropy: 1.5334 - val_loss: 1.6042 - val_accuracy: 0.2307 - val_categorical_crossentropy: 1.6042
# Epoch 69/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.5225 - accuracy: 0.3112 - categorical_crossentropy: 1.5225 - val_loss: 1.6068 - val_accuracy: 0.2194 - val_categorical_crossentropy: 1.6068
# Epoch 70/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5292 - accuracy: 0.2871 - categorical_crossentropy: 1.5292 - val_loss: 1.6105 - val_accuracy: 0.2250 - val_categorical_crossentropy: 1.6105
# Epoch 71/2000
# 26/26 [==============================] - 1s 52ms/step - loss: 1.5355 - accuracy: 0.2847 - categorical_crossentropy: 1.5355 - val_loss: 1.6064 - val_accuracy: 0.2278 - val_categorical_crossentropy: 1.6064
# Epoch 72/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5293 - accuracy: 0.2967 - categorical_crossentropy: 1.5293 - val_loss: 1.6177 - val_accuracy: 0.2152 - val_categorical_crossentropy: 1.6177
# Epoch 73/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5203 - accuracy: 0.3088 - categorical_crossentropy: 1.5203 - val_loss: 1.6239 - val_accuracy: 0.2250 - val_categorical_crossentropy: 1.6239
# Epoch 74/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5158 - accuracy: 0.3179 - categorical_crossentropy: 1.5158 - val_loss: 1.6257 - val_accuracy: 0.2152 - val_categorical_crossentropy: 1.6257
# Epoch 75/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5184 - accuracy: 0.3052 - categorical_crossentropy: 1.5184 - val_loss: 1.6382 - val_accuracy: 0.2194 - val_categorical_crossentropy: 1.6382
# Epoch 76/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5128 - accuracy: 0.3064 - categorical_crossentropy: 1.5128 - val_loss: 1.6464 - val_accuracy: 0.1913 - val_categorical_crossentropy: 1.6464
# Epoch 77/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5234 - accuracy: 0.3082 - categorical_crossentropy: 1.5234 - val_loss: 1.6190 - val_accuracy: 0.2278 - val_categorical_crossentropy: 1.6190
# Epoch 78/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5247 - accuracy: 0.2967 - categorical_crossentropy: 1.5247 - val_loss: 1.6118 - val_accuracy: 0.2264 - val_categorical_crossentropy: 1.6118
# Epoch 79/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5092 - accuracy: 0.3076 - categorical_crossentropy: 1.5092 - val_loss: 1.6154 - val_accuracy: 0.2335 - val_categorical_crossentropy: 1.6154
# Epoch 80/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5131 - accuracy: 0.3233 - categorical_crossentropy: 1.5131 - val_loss: 1.6258 - val_accuracy: 0.2278 - val_categorical_crossentropy: 1.6258
# Epoch 81/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5169 - accuracy: 0.3076 - categorical_crossentropy: 1.5169 - val_loss: 1.6246 - val_accuracy: 0.2250 - val_categorical_crossentropy: 1.6246
# Epoch 82/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5135 - accuracy: 0.3070 - categorical_crossentropy: 1.5135 - val_loss: 1.6337 - val_accuracy: 0.2236 - val_categorical_crossentropy: 1.6337
# Epoch 83/2000
# 26/26 [==============================] - 1s 52ms/step - loss: 1.4989 - accuracy: 0.3154 - categorical_crossentropy: 1.4989 - val_loss: 1.6512 - val_accuracy: 0.2152 - val_categorical_crossentropy: 1.6512
# Epoch 84/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4952 - accuracy: 0.3305 - categorical_crossentropy: 1.4952 - val_loss: 1.6532 - val_accuracy: 0.2138 - val_categorical_crossentropy: 1.6532
# Epoch 85/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5010 - accuracy: 0.3100 - categorical_crossentropy: 1.5010 - val_loss: 1.6319 - val_accuracy: 0.2250 - val_categorical_crossentropy: 1.6319
# Epoch 86/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4998 - accuracy: 0.3353 - categorical_crossentropy: 1.4998 - val_loss: 1.6493 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.6493
# Epoch 87/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4839 - accuracy: 0.3359 - categorical_crossentropy: 1.4839 - val_loss: 1.6666 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.6666
# Epoch 88/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4800 - accuracy: 0.3468 - categorical_crossentropy: 1.4800 - val_loss: 1.6793 - val_accuracy: 0.2096 - val_categorical_crossentropy: 1.6793
# Epoch 89/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4968 - accuracy: 0.3239 - categorical_crossentropy: 1.4968 - val_loss: 1.6526 - val_accuracy: 0.2096 - val_categorical_crossentropy: 1.6526
# Epoch 90/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4751 - accuracy: 0.3426 - categorical_crossentropy: 1.4751 - val_loss: 1.6793 - val_accuracy: 0.2110 - val_categorical_crossentropy: 1.6793
# Epoch 91/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.4967 - accuracy: 0.3281 - categorical_crossentropy: 1.4967 - val_loss: 1.6552 - val_accuracy: 0.2124 - val_categorical_crossentropy: 1.6552
# Epoch 92/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4923 - accuracy: 0.3444 - categorical_crossentropy: 1.4923 - val_loss: 1.6444 - val_accuracy: 0.2321 - val_categorical_crossentropy: 1.6444
# Epoch 93/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4813 - accuracy: 0.3462 - categorical_crossentropy: 1.4813 - val_loss: 1.6555 - val_accuracy: 0.2307 - val_categorical_crossentropy: 1.6555
# Epoch 94/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.4908 - accuracy: 0.3179 - categorical_crossentropy: 1.4908 - val_loss: 1.6501 - val_accuracy: 0.2293 - val_categorical_crossentropy: 1.6501
# Epoch 95/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4831 - accuracy: 0.3245 - categorical_crossentropy: 1.4831 - val_loss: 1.6474 - val_accuracy: 0.2124 - val_categorical_crossentropy: 1.6474
# Epoch 96/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4550 - accuracy: 0.3619 - categorical_crossentropy: 1.4550 - val_loss: 1.6800 - val_accuracy: 0.2180 - val_categorical_crossentropy: 1.6800
# Epoch 97/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4770 - accuracy: 0.3444 - categorical_crossentropy: 1.4770 - val_loss: 1.6595 - val_accuracy: 0.2321 - val_categorical_crossentropy: 1.6595
# Epoch 98/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4834 - accuracy: 0.3281 - categorical_crossentropy: 1.4834 - val_loss: 1.6504 - val_accuracy: 0.2278 - val_categorical_crossentropy: 1.6504
# Epoch 99/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4813 - accuracy: 0.3335 - categorical_crossentropy: 1.4813 - val_loss: 1.6621 - val_accuracy: 0.2180 - val_categorical_crossentropy: 1.6621
# Epoch 100/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4770 - accuracy: 0.3420 - categorical_crossentropy: 1.4770 - val_loss: 1.6565 - val_accuracy: 0.2278 - val_categorical_crossentropy: 1.6565
# Epoch 101/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4657 - accuracy: 0.3486 - categorical_crossentropy: 1.4657 - val_loss: 1.6642 - val_accuracy: 0.2250 - val_categorical_crossentropy: 1.6642
# Epoch 102/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4509 - accuracy: 0.3589 - categorical_crossentropy: 1.4509 - val_loss: 1.6882 - val_accuracy: 0.2166 - val_categorical_crossentropy: 1.6882
# Epoch 103/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4583 - accuracy: 0.3510 - categorical_crossentropy: 1.4583 - val_loss: 1.6594 - val_accuracy: 0.2278 - val_categorical_crossentropy: 1.6594
# Epoch 104/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4624 - accuracy: 0.3661 - categorical_crossentropy: 1.4624 - val_loss: 1.6731 - val_accuracy: 0.2307 - val_categorical_crossentropy: 1.6731
# Epoch 105/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4412 - accuracy: 0.3745 - categorical_crossentropy: 1.4412 - val_loss: 1.7003 - val_accuracy: 0.2222 - val_categorical_crossentropy: 1.7003
# Epoch 106/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4541 - accuracy: 0.3528 - categorical_crossentropy: 1.4541 - val_loss: 1.6820 - val_accuracy: 0.2166 - val_categorical_crossentropy: 1.6820
# Epoch 107/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.4445 - accuracy: 0.3824 - categorical_crossentropy: 1.4445 - val_loss: 1.6857 - val_accuracy: 0.2222 - val_categorical_crossentropy: 1.6857
# Epoch 108/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4469 - accuracy: 0.3782 - categorical_crossentropy: 1.4469 - val_loss: 1.6907 - val_accuracy: 0.2180 - val_categorical_crossentropy: 1.6907
# Epoch 109/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4513 - accuracy: 0.3583 - categorical_crossentropy: 1.4513 - val_loss: 1.6793 - val_accuracy: 0.2222 - val_categorical_crossentropy: 1.6793
# Epoch 110/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4476 - accuracy: 0.3607 - categorical_crossentropy: 1.4476 - val_loss: 1.6796 - val_accuracy: 0.2236 - val_categorical_crossentropy: 1.6796
# Epoch 111/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4439 - accuracy: 0.3589 - categorical_crossentropy: 1.4439 - val_loss: 1.6750 - val_accuracy: 0.2194 - val_categorical_crossentropy: 1.6750
# Epoch 112/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4413 - accuracy: 0.3673 - categorical_crossentropy: 1.4413 - val_loss: 1.6773 - val_accuracy: 0.2194 - val_categorical_crossentropy: 1.6773
# Epoch 113/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4154 - accuracy: 0.3752 - categorical_crossentropy: 1.4154 - val_loss: 1.7078 - val_accuracy: 0.2194 - val_categorical_crossentropy: 1.7078
# Epoch 114/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4376 - accuracy: 0.3848 - categorical_crossentropy: 1.4376 - val_loss: 1.6937 - val_accuracy: 0.2138 - val_categorical_crossentropy: 1.6937
# Epoch 115/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4220 - accuracy: 0.3842 - categorical_crossentropy: 1.4220 - val_loss: 1.6967 - val_accuracy: 0.2222 - val_categorical_crossentropy: 1.6967
# Epoch 116/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4200 - accuracy: 0.3951 - categorical_crossentropy: 1.4200 - val_loss: 1.7023 - val_accuracy: 0.2138 - val_categorical_crossentropy: 1.7023
# Epoch 117/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3988 - accuracy: 0.3896 - categorical_crossentropy: 1.3988 - val_loss: 1.7199 - val_accuracy: 0.2264 - val_categorical_crossentropy: 1.7199
# Epoch 118/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.4118 - accuracy: 0.3788 - categorical_crossentropy: 1.4118 - val_loss: 1.6912 - val_accuracy: 0.2264 - val_categorical_crossentropy: 1.6912
# Epoch 119/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4112 - accuracy: 0.3981 - categorical_crossentropy: 1.4112 - val_loss: 1.7175 - val_accuracy: 0.2475 - val_categorical_crossentropy: 1.7175
# Epoch 120/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4187 - accuracy: 0.3884 - categorical_crossentropy: 1.4187 - val_loss: 1.7008 - val_accuracy: 0.2391 - val_categorical_crossentropy: 1.7008
# Epoch 121/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4062 - accuracy: 0.3932 - categorical_crossentropy: 1.4062 - val_loss: 1.7122 - val_accuracy: 0.2405 - val_categorical_crossentropy: 1.7122
# Epoch 122/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4051 - accuracy: 0.3957 - categorical_crossentropy: 1.4051 - val_loss: 1.7236 - val_accuracy: 0.2349 - val_categorical_crossentropy: 1.7236
# Epoch 123/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.4187 - accuracy: 0.3848 - categorical_crossentropy: 1.4187 - val_loss: 1.7096 - val_accuracy: 0.2349 - val_categorical_crossentropy: 1.7096
# Epoch 124/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3903 - accuracy: 0.4011 - categorical_crossentropy: 1.3903 - val_loss: 1.7262 - val_accuracy: 0.2236 - val_categorical_crossentropy: 1.7262
# Epoch 125/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4105 - accuracy: 0.3920 - categorical_crossentropy: 1.4105 - val_loss: 1.7271 - val_accuracy: 0.2264 - val_categorical_crossentropy: 1.7271
# Epoch 126/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4056 - accuracy: 0.3957 - categorical_crossentropy: 1.4056 - val_loss: 1.7139 - val_accuracy: 0.2349 - val_categorical_crossentropy: 1.7139
# Epoch 127/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3963 - accuracy: 0.4041 - categorical_crossentropy: 1.3963 - val_loss: 1.7336 - val_accuracy: 0.2068 - val_categorical_crossentropy: 1.7336
# Epoch 128/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 1.4048 - accuracy: 0.4071 - categorical_crossentropy: 1.4048 - val_loss: 1.7168 - val_accuracy: 0.2250 - val_categorical_crossentropy: 1.7168
# Epoch 129/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3887 - accuracy: 0.3981 - categorical_crossentropy: 1.3887 - val_loss: 1.7458 - val_accuracy: 0.2194 - val_categorical_crossentropy: 1.7458
# Epoch 130/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.3889 - accuracy: 0.4059 - categorical_crossentropy: 1.3889 - val_loss: 1.7472 - val_accuracy: 0.2222 - val_categorical_crossentropy: 1.7472
# Epoch 131/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3850 - accuracy: 0.3957 - categorical_crossentropy: 1.3850 - val_loss: 1.7291 - val_accuracy: 0.2293 - val_categorical_crossentropy: 1.7291
# Epoch 132/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3587 - accuracy: 0.4276 - categorical_crossentropy: 1.3587 - val_loss: 1.7566 - val_accuracy: 0.2335 - val_categorical_crossentropy: 1.7566
# Epoch 133/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3728 - accuracy: 0.3993 - categorical_crossentropy: 1.3728 - val_loss: 1.7436 - val_accuracy: 0.2377 - val_categorical_crossentropy: 1.7436
# Epoch 134/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3645 - accuracy: 0.4071 - categorical_crossentropy: 1.3645 - val_loss: 1.7476 - val_accuracy: 0.2377 - val_categorical_crossentropy: 1.7476
# Epoch 135/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3796 - accuracy: 0.4065 - categorical_crossentropy: 1.3796 - val_loss: 1.7380 - val_accuracy: 0.2433 - val_categorical_crossentropy: 1.7380
# Epoch 136/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.3657 - accuracy: 0.4228 - categorical_crossentropy: 1.3657 - val_loss: 1.7806 - val_accuracy: 0.2278 - val_categorical_crossentropy: 1.7806
# Epoch 137/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3618 - accuracy: 0.4270 - categorical_crossentropy: 1.3618 - val_loss: 1.7732 - val_accuracy: 0.2307 - val_categorical_crossentropy: 1.7732
# Epoch 138/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.3499 - accuracy: 0.4252 - categorical_crossentropy: 1.3499 - val_loss: 1.7705 - val_accuracy: 0.2349 - val_categorical_crossentropy: 1.7705
# Epoch 139/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.3747 - accuracy: 0.4168 - categorical_crossentropy: 1.3747 - val_loss: 1.7543 - val_accuracy: 0.2349 - val_categorical_crossentropy: 1.7543
# Epoch 140/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3585 - accuracy: 0.4282 - categorical_crossentropy: 1.3585 - val_loss: 1.7552 - val_accuracy: 0.2489 - val_categorical_crossentropy: 1.7552
# Epoch 141/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3356 - accuracy: 0.4312 - categorical_crossentropy: 1.3356 - val_loss: 1.7658 - val_accuracy: 0.2307 - val_categorical_crossentropy: 1.7658
# Epoch 142/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3367 - accuracy: 0.4451 - categorical_crossentropy: 1.3367 - val_loss: 1.7709 - val_accuracy: 0.2222 - val_categorical_crossentropy: 1.7709
# Epoch 143/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3582 - accuracy: 0.4180 - categorical_crossentropy: 1.3582 - val_loss: 1.7501 - val_accuracy: 0.2293 - val_categorical_crossentropy: 1.7501
# Epoch 144/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3485 - accuracy: 0.4343 - categorical_crossentropy: 1.3485 - val_loss: 1.7430 - val_accuracy: 0.2391 - val_categorical_crossentropy: 1.7430
# Epoch 145/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3434 - accuracy: 0.4306 - categorical_crossentropy: 1.3434 - val_loss: 1.7481 - val_accuracy: 0.2560 - val_categorical_crossentropy: 1.7481
# Epoch 146/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3558 - accuracy: 0.4349 - categorical_crossentropy: 1.3558 - val_loss: 1.7672 - val_accuracy: 0.2307 - val_categorical_crossentropy: 1.7672
# Epoch 147/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3342 - accuracy: 0.4192 - categorical_crossentropy: 1.3342 - val_loss: 1.7757 - val_accuracy: 0.2335 - val_categorical_crossentropy: 1.7757
# Epoch 148/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3357 - accuracy: 0.4397 - categorical_crossentropy: 1.3357 - val_loss: 1.7900 - val_accuracy: 0.2433 - val_categorical_crossentropy: 1.7900
# Epoch 149/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3492 - accuracy: 0.4270 - categorical_crossentropy: 1.3492 - val_loss: 1.7969 - val_accuracy: 0.2391 - val_categorical_crossentropy: 1.7969
# Epoch 150/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3290 - accuracy: 0.4264 - categorical_crossentropy: 1.3290 - val_loss: 1.7770 - val_accuracy: 0.2250 - val_categorical_crossentropy: 1.7770
# Epoch 151/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3443 - accuracy: 0.4397 - categorical_crossentropy: 1.3443 - val_loss: 1.7704 - val_accuracy: 0.2250 - val_categorical_crossentropy: 1.7704
# Epoch 152/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3292 - accuracy: 0.4318 - categorical_crossentropy: 1.3292 - val_loss: 1.7982 - val_accuracy: 0.2391 - val_categorical_crossentropy: 1.7982
# Epoch 153/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3476 - accuracy: 0.4331 - categorical_crossentropy: 1.3476 - val_loss: 1.7713 - val_accuracy: 0.2391 - val_categorical_crossentropy: 1.7713
# Epoch 154/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3124 - accuracy: 0.4457 - categorical_crossentropy: 1.3124 - val_loss: 1.8312 - val_accuracy: 0.2335 - val_categorical_crossentropy: 1.8312
# Epoch 155/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3277 - accuracy: 0.4530 - categorical_crossentropy: 1.3277 - val_loss: 1.7780 - val_accuracy: 0.2335 - val_categorical_crossentropy: 1.7780
# Epoch 156/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3227 - accuracy: 0.4427 - categorical_crossentropy: 1.3227 - val_loss: 1.8176 - val_accuracy: 0.2405 - val_categorical_crossentropy: 1.8176
# Epoch 157/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3193 - accuracy: 0.4505 - categorical_crossentropy: 1.3193 - val_loss: 1.8310 - val_accuracy: 0.2391 - val_categorical_crossentropy: 1.8310
# Epoch 158/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3176 - accuracy: 0.4331 - categorical_crossentropy: 1.3176 - val_loss: 1.8292 - val_accuracy: 0.2349 - val_categorical_crossentropy: 1.8292
# Epoch 159/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3148 - accuracy: 0.4451 - categorical_crossentropy: 1.3148 - val_loss: 1.8668 - val_accuracy: 0.2321 - val_categorical_crossentropy: 1.8668
# Epoch 160/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3109 - accuracy: 0.4560 - categorical_crossentropy: 1.3109 - val_loss: 1.9219 - val_accuracy: 0.2363 - val_categorical_crossentropy: 1.9219
# Epoch 161/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3075 - accuracy: 0.4367 - categorical_crossentropy: 1.3075 - val_loss: 1.9373 - val_accuracy: 0.2419 - val_categorical_crossentropy: 1.9373
# Epoch 162/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.3156 - accuracy: 0.4487 - categorical_crossentropy: 1.3156 - val_loss: 1.8728 - val_accuracy: 0.2293 - val_categorical_crossentropy: 1.8728
# Epoch 163/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.3086 - accuracy: 0.4530 - categorical_crossentropy: 1.3086 - val_loss: 1.9012 - val_accuracy: 0.2321 - val_categorical_crossentropy: 1.9012
# Epoch 164/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.2962 - accuracy: 0.4572 - categorical_crossentropy: 1.2962 - val_loss: 1.9462 - val_accuracy: 0.2293 - val_categorical_crossentropy: 1.9462
# Epoch 165/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.2831 - accuracy: 0.4710 - categorical_crossentropy: 1.2831 - val_loss: 1.9457 - val_accuracy: 0.2264 - val_categorical_crossentropy: 1.9457
# Epoch 166/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2887 - accuracy: 0.4530 - categorical_crossentropy: 1.2887 - val_loss: 2.0015 - val_accuracy: 0.2293 - val_categorical_crossentropy: 2.0015
# Epoch 167/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.3183 - accuracy: 0.4391 - categorical_crossentropy: 1.3183 - val_loss: 1.9948 - val_accuracy: 0.2293 - val_categorical_crossentropy: 1.9948
# Epoch 168/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.2926 - accuracy: 0.4596 - categorical_crossentropy: 1.2926 - val_loss: 2.0173 - val_accuracy: 0.2236 - val_categorical_crossentropy: 2.0173
# Epoch 169/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2977 - accuracy: 0.4409 - categorical_crossentropy: 1.2977 - val_loss: 1.9596 - val_accuracy: 0.2321 - val_categorical_crossentropy: 1.9596
# Epoch 170/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2911 - accuracy: 0.4584 - categorical_crossentropy: 1.2911 - val_loss: 1.9613 - val_accuracy: 0.2293 - val_categorical_crossentropy: 1.9613
# Epoch 171/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.3023 - accuracy: 0.4487 - categorical_crossentropy: 1.3023 - val_loss: 2.0080 - val_accuracy: 0.2363 - val_categorical_crossentropy: 2.0080
# Epoch 172/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2790 - accuracy: 0.4511 - categorical_crossentropy: 1.2790 - val_loss: 2.0834 - val_accuracy: 0.2236 - val_categorical_crossentropy: 2.0834
# Epoch 173/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2689 - accuracy: 0.4723 - categorical_crossentropy: 1.2689 - val_loss: 2.0545 - val_accuracy: 0.2236 - val_categorical_crossentropy: 2.0545
# Epoch 174/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.2604 - accuracy: 0.4753 - categorical_crossentropy: 1.2604 - val_loss: 2.1489 - val_accuracy: 0.2250 - val_categorical_crossentropy: 2.1489
# Epoch 175/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.2746 - accuracy: 0.4741 - categorical_crossentropy: 1.2746 - val_loss: 2.1572 - val_accuracy: 0.2194 - val_categorical_crossentropy: 2.1572
# Epoch 176/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2875 - accuracy: 0.4596 - categorical_crossentropy: 1.2875 - val_loss: 2.0615 - val_accuracy: 0.2250 - val_categorical_crossentropy: 2.0615
# Epoch 177/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.2863 - accuracy: 0.4662 - categorical_crossentropy: 1.2863 - val_loss: 2.1100 - val_accuracy: 0.2180 - val_categorical_crossentropy: 2.1100
# Epoch 178/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2804 - accuracy: 0.4680 - categorical_crossentropy: 1.2804 - val_loss: 2.1186 - val_accuracy: 0.2180 - val_categorical_crossentropy: 2.1186
# Epoch 179/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2821 - accuracy: 0.4590 - categorical_crossentropy: 1.2821 - val_loss: 2.1939 - val_accuracy: 0.2222 - val_categorical_crossentropy: 2.1939
# Epoch 180/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2716 - accuracy: 0.4530 - categorical_crossentropy: 1.2716 - val_loss: 2.3517 - val_accuracy: 0.2307 - val_categorical_crossentropy: 2.3517
# Epoch 181/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.2739 - accuracy: 0.4578 - categorical_crossentropy: 1.2739 - val_loss: 2.3067 - val_accuracy: 0.2307 - val_categorical_crossentropy: 2.3067
# Epoch 182/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.2305 - accuracy: 0.5018 - categorical_crossentropy: 1.2305 - val_loss: 2.5203 - val_accuracy: 0.2194 - val_categorical_crossentropy: 2.5203
# Epoch 183/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2676 - accuracy: 0.4620 - categorical_crossentropy: 1.2676 - val_loss: 2.3244 - val_accuracy: 0.2363 - val_categorical_crossentropy: 2.3244
# Epoch 184/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.2711 - accuracy: 0.4680 - categorical_crossentropy: 1.2711 - val_loss: 2.2578 - val_accuracy: 0.2307 - val_categorical_crossentropy: 2.2578
# Epoch 185/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2670 - accuracy: 0.4517 - categorical_crossentropy: 1.2670 - val_loss: 2.2843 - val_accuracy: 0.2363 - val_categorical_crossentropy: 2.2843
# Epoch 186/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.2718 - accuracy: 0.4620 - categorical_crossentropy: 1.2718 - val_loss: 2.3274 - val_accuracy: 0.2321 - val_categorical_crossentropy: 2.3274
# Epoch 187/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2623 - accuracy: 0.4777 - categorical_crossentropy: 1.2623 - val_loss: 2.3334 - val_accuracy: 0.2321 - val_categorical_crossentropy: 2.3334
# Epoch 188/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.2450 - accuracy: 0.4753 - categorical_crossentropy: 1.2450 - val_loss: 2.4178 - val_accuracy: 0.2222 - val_categorical_crossentropy: 2.4178
# Epoch 189/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 1.2487 - accuracy: 0.4710 - categorical_crossentropy: 1.2487 - val_loss: 2.4231 - val_accuracy: 0.2307 - val_categorical_crossentropy: 2.4231
# Epoch 190/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 1.2663 - accuracy: 0.4723 - categorical_crossentropy: 1.2663 - val_loss: 2.4243 - val_accuracy: 0.2321 - val_categorical_crossentropy: 2.4243
# Epoch 191/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 1.2411 - accuracy: 0.4771 - categorical_crossentropy: 1.2411 - val_loss: 2.4152 - val_accuracy: 0.2194 - val_categorical_crossentropy: 2.4152
# Epoch 192/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 1.2284 - accuracy: 0.4861 - categorical_crossentropy: 1.2284 - val_loss: 2.5748 - val_accuracy: 0.2236 - val_categorical_crossentropy: 2.5748
# Epoch 193/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 1.2543 - accuracy: 0.4831 - categorical_crossentropy: 1.2543 - val_loss: 2.4595 - val_accuracy: 0.2236 - val_categorical_crossentropy: 2.4595
# Epoch 194/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2351 - accuracy: 0.4891 - categorical_crossentropy: 1.2351 - val_loss: 2.5166 - val_accuracy: 0.2222 - val_categorical_crossentropy: 2.5166
# Epoch 195/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2176 - accuracy: 0.4952 - categorical_crossentropy: 1.2176 - val_loss: 2.5985 - val_accuracy: 0.2194 - val_categorical_crossentropy: 2.5985
# Epoch 196/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2525 - accuracy: 0.4795 - categorical_crossentropy: 1.2525 - val_loss: 2.3882 - val_accuracy: 0.2250 - val_categorical_crossentropy: 2.3882
# Epoch 197/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.2429 - accuracy: 0.4891 - categorical_crossentropy: 1.2429 - val_loss: 2.4052 - val_accuracy: 0.2307 - val_categorical_crossentropy: 2.4052
# Epoch 198/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2226 - accuracy: 0.4994 - categorical_crossentropy: 1.2226 - val_loss: 2.4823 - val_accuracy: 0.2307 - val_categorical_crossentropy: 2.4823
# Epoch 199/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2238 - accuracy: 0.4885 - categorical_crossentropy: 1.2238 - val_loss: 2.4399 - val_accuracy: 0.2222 - val_categorical_crossentropy: 2.4399
# Epoch 200/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2223 - accuracy: 0.4928 - categorical_crossentropy: 1.2223 - val_loss: 2.5283 - val_accuracy: 0.2222 - val_categorical_crossentropy: 2.5283
# Epoch 201/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2215 - accuracy: 0.5030 - categorical_crossentropy: 1.2215 - val_loss: 2.6208 - val_accuracy: 0.2250 - val_categorical_crossentropy: 2.6208
# Epoch 202/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.2095 - accuracy: 0.4891 - categorical_crossentropy: 1.2095 - val_loss: 2.6545 - val_accuracy: 0.2194 - val_categorical_crossentropy: 2.6545
# Epoch 203/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2099 - accuracy: 0.5090 - categorical_crossentropy: 1.2099 - val_loss: 2.4325 - val_accuracy: 0.2307 - val_categorical_crossentropy: 2.4325
# Epoch 204/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2311 - accuracy: 0.4988 - categorical_crossentropy: 1.2311 - val_loss: 2.4309 - val_accuracy: 0.2335 - val_categorical_crossentropy: 2.4309
# Epoch 205/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2086 - accuracy: 0.4970 - categorical_crossentropy: 1.2086 - val_loss: 2.4741 - val_accuracy: 0.2335 - val_categorical_crossentropy: 2.4741
# Epoch 206/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.2119 - accuracy: 0.5012 - categorical_crossentropy: 1.2119 - val_loss: 2.4267 - val_accuracy: 0.2293 - val_categorical_crossentropy: 2.4267
# Epoch 207/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.1857 - accuracy: 0.5271 - categorical_crossentropy: 1.1857 - val_loss: 2.6790 - val_accuracy: 0.2194 - val_categorical_crossentropy: 2.6790
# Epoch 208/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2245 - accuracy: 0.4861 - categorical_crossentropy: 1.2245 - val_loss: 2.4902 - val_accuracy: 0.2250 - val_categorical_crossentropy: 2.4902
# Epoch 209/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 1.1980 - accuracy: 0.5103 - categorical_crossentropy: 1.1980 - val_loss: 2.7417 - val_accuracy: 0.2194 - val_categorical_crossentropy: 2.7417
# Epoch 210/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.1979 - accuracy: 0.5018 - categorical_crossentropy: 1.1979 - val_loss: 2.6656 - val_accuracy: 0.2264 - val_categorical_crossentropy: 2.6656
# Epoch 211/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2036 - accuracy: 0.5000 - categorical_crossentropy: 1.2036 - val_loss: 2.5713 - val_accuracy: 0.2264 - val_categorical_crossentropy: 2.5713
# Epoch 212/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.1980 - accuracy: 0.5127 - categorical_crossentropy: 1.1980 - val_loss: 2.6580 - val_accuracy: 0.2236 - val_categorical_crossentropy: 2.6580
# Epoch 213/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2214 - accuracy: 0.5018 - categorical_crossentropy: 1.2214 - val_loss: 2.5145 - val_accuracy: 0.2222 - val_categorical_crossentropy: 2.5145
# Epoch 214/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2009 - accuracy: 0.5103 - categorical_crossentropy: 1.2009 - val_loss: 2.4718 - val_accuracy: 0.2349 - val_categorical_crossentropy: 2.4718
# Epoch 215/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.2065 - accuracy: 0.5151 - categorical_crossentropy: 1.2065 - val_loss: 2.6509 - val_accuracy: 0.2180 - val_categorical_crossentropy: 2.6509
# Epoch 216/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 1.1573 - accuracy: 0.5163 - categorical_crossentropy: 1.1573 - val_loss: 2.7297 - val_accuracy: 0.2138 - val_categorical_crossentropy: 2.7297
# Epoch 217/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.1966 - accuracy: 0.5115 - categorical_crossentropy: 1.1966 - val_loss: 2.4658 - val_accuracy: 0.2377 - val_categorical_crossentropy: 2.4658
# Epoch 218/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 1.1916 - accuracy: 0.4970 - categorical_crossentropy: 1.1916 - val_loss: 2.6196 - val_accuracy: 0.2278 - val_categorical_crossentropy: 2.6196
# Epoch 219/2000
# ...
# Epoch 1929/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1031 - accuracy: 0.9626 - categorical_crossentropy: 0.1031 - val_loss: 20.1746 - val_accuracy: 0.2250 - val_categorical_crossentropy: 20.1746
# Epoch 1930/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0950 - accuracy: 0.9656 - categorical_crossentropy: 0.0950 - val_loss: 20.3424 - val_accuracy: 0.2222 - val_categorical_crossentropy: 20.3424
# Epoch 1931/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1001 - accuracy: 0.9656 - categorical_crossentropy: 0.1001 - val_loss: 19.4294 - val_accuracy: 0.2278 - val_categorical_crossentropy: 19.4294
# Epoch 1932/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0898 - accuracy: 0.9723 - categorical_crossentropy: 0.0898 - val_loss: 22.5993 - val_accuracy: 0.2222 - val_categorical_crossentropy: 22.5993
# Epoch 1933/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1041 - accuracy: 0.9674 - categorical_crossentropy: 0.1041 - val_loss: 20.7273 - val_accuracy: 0.2278 - val_categorical_crossentropy: 20.7273
# Epoch 1934/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0984 - accuracy: 0.9662 - categorical_crossentropy: 0.0984 - val_loss: 24.1662 - val_accuracy: 0.2250 - val_categorical_crossentropy: 24.1662
# Epoch 1935/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0818 - accuracy: 0.9729 - categorical_crossentropy: 0.0818 - val_loss: 21.9583 - val_accuracy: 0.2250 - val_categorical_crossentropy: 21.9583
# Epoch 1936/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0866 - accuracy: 0.9729 - categorical_crossentropy: 0.0866 - val_loss: 24.4787 - val_accuracy: 0.2293 - val_categorical_crossentropy: 24.4787
# Epoch 1937/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0913 - accuracy: 0.9698 - categorical_crossentropy: 0.0913 - val_loss: 21.2199 - val_accuracy: 0.2307 - val_categorical_crossentropy: 21.2199
# Epoch 1938/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1128 - accuracy: 0.9596 - categorical_crossentropy: 0.1128 - val_loss: 22.6258 - val_accuracy: 0.2307 - val_categorical_crossentropy: 22.6258
# Epoch 1939/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0948 - accuracy: 0.9686 - categorical_crossentropy: 0.0948 - val_loss: 19.3890 - val_accuracy: 0.2278 - val_categorical_crossentropy: 19.3890
# Epoch 1940/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0919 - accuracy: 0.9656 - categorical_crossentropy: 0.0919 - val_loss: 22.7435 - val_accuracy: 0.2236 - val_categorical_crossentropy: 22.7435
# Epoch 1941/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0901 - accuracy: 0.9735 - categorical_crossentropy: 0.0901 - val_loss: 26.8414 - val_accuracy: 0.2208 - val_categorical_crossentropy: 26.8414
# Epoch 1942/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0833 - accuracy: 0.9723 - categorical_crossentropy: 0.0833 - val_loss: 19.9117 - val_accuracy: 0.2307 - val_categorical_crossentropy: 19.9117
# Epoch 1943/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1069 - accuracy: 0.9674 - categorical_crossentropy: 0.1069 - val_loss: 24.6071 - val_accuracy: 0.2194 - val_categorical_crossentropy: 24.6071
# Epoch 1944/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1021 - accuracy: 0.9704 - categorical_crossentropy: 0.1021 - val_loss: 20.9716 - val_accuracy: 0.2307 - val_categorical_crossentropy: 20.9716
# Epoch 1945/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0962 - accuracy: 0.9644 - categorical_crossentropy: 0.0962 - val_loss: 24.4667 - val_accuracy: 0.2180 - val_categorical_crossentropy: 24.4667
# Epoch 1946/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1018 - accuracy: 0.9620 - categorical_crossentropy: 0.1018 - val_loss: 25.2384 - val_accuracy: 0.2264 - val_categorical_crossentropy: 25.2384
# Epoch 1947/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 0.0892 - accuracy: 0.9729 - categorical_crossentropy: 0.0892 - val_loss: 25.1305 - val_accuracy: 0.2222 - val_categorical_crossentropy: 25.1305
# Epoch 1948/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1012 - accuracy: 0.9674 - categorical_crossentropy: 0.1012 - val_loss: 25.5460 - val_accuracy: 0.2250 - val_categorical_crossentropy: 25.5460
# Epoch 1949/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0865 - accuracy: 0.9741 - categorical_crossentropy: 0.0865 - val_loss: 21.8343 - val_accuracy: 0.2250 - val_categorical_crossentropy: 21.8343
# Epoch 1950/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1000 - accuracy: 0.9614 - categorical_crossentropy: 0.1000 - val_loss: 27.7852 - val_accuracy: 0.2208 - val_categorical_crossentropy: 27.7852
# Epoch 1951/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0858 - accuracy: 0.9723 - categorical_crossentropy: 0.0858 - val_loss: 23.6947 - val_accuracy: 0.2222 - val_categorical_crossentropy: 23.6947
# Epoch 1952/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1150 - accuracy: 0.9656 - categorical_crossentropy: 0.1150 - val_loss: 25.3128 - val_accuracy: 0.2222 - val_categorical_crossentropy: 25.3128
# Epoch 1953/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0976 - accuracy: 0.9680 - categorical_crossentropy: 0.0976 - val_loss: 21.0644 - val_accuracy: 0.2222 - val_categorical_crossentropy: 21.0644
# Epoch 1954/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0907 - accuracy: 0.9704 - categorical_crossentropy: 0.0907 - val_loss: 22.6062 - val_accuracy: 0.2250 - val_categorical_crossentropy: 22.6062
# Epoch 1955/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0787 - accuracy: 0.9686 - categorical_crossentropy: 0.0787 - val_loss: 23.0748 - val_accuracy: 0.2208 - val_categorical_crossentropy: 23.0748
# Epoch 1956/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0948 - accuracy: 0.9717 - categorical_crossentropy: 0.0948 - val_loss: 21.5922 - val_accuracy: 0.2222 - val_categorical_crossentropy: 21.5922
# Epoch 1957/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0917 - accuracy: 0.9717 - categorical_crossentropy: 0.0917 - val_loss: 19.0275 - val_accuracy: 0.2138 - val_categorical_crossentropy: 19.0275
# Epoch 1958/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1020 - accuracy: 0.9632 - categorical_crossentropy: 0.1020 - val_loss: 19.7166 - val_accuracy: 0.2194 - val_categorical_crossentropy: 19.7166
# Epoch 1959/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1020 - accuracy: 0.9650 - categorical_crossentropy: 0.1020 - val_loss: 19.6977 - val_accuracy: 0.2208 - val_categorical_crossentropy: 19.6977
# Epoch 1960/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 0.1094 - accuracy: 0.9704 - categorical_crossentropy: 0.1094 - val_loss: 22.1446 - val_accuracy: 0.2222 - val_categorical_crossentropy: 22.1446
# Epoch 1961/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0913 - accuracy: 0.9686 - categorical_crossentropy: 0.0913 - val_loss: 21.4435 - val_accuracy: 0.2236 - val_categorical_crossentropy: 21.4435
# Epoch 1962/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0768 - accuracy: 0.9771 - categorical_crossentropy: 0.0768 - val_loss: 20.5621 - val_accuracy: 0.2250 - val_categorical_crossentropy: 20.5621
# Epoch 1963/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0981 - accuracy: 0.9638 - categorical_crossentropy: 0.0981 - val_loss: 25.2852 - val_accuracy: 0.2180 - val_categorical_crossentropy: 25.2852
# Epoch 1964/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0957 - accuracy: 0.9735 - categorical_crossentropy: 0.0957 - val_loss: 22.6444 - val_accuracy: 0.2208 - val_categorical_crossentropy: 22.6444
# Epoch 1965/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0856 - accuracy: 0.9735 - categorical_crossentropy: 0.0856 - val_loss: 20.6631 - val_accuracy: 0.2222 - val_categorical_crossentropy: 20.6631
# Epoch 1966/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1044 - accuracy: 0.9632 - categorical_crossentropy: 0.1044 - val_loss: 24.6156 - val_accuracy: 0.2250 - val_categorical_crossentropy: 24.6156
# Epoch 1967/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1025 - accuracy: 0.9638 - categorical_crossentropy: 0.1025 - val_loss: 20.9174 - val_accuracy: 0.2194 - val_categorical_crossentropy: 20.9174
# Epoch 1968/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0999 - accuracy: 0.9650 - categorical_crossentropy: 0.0999 - val_loss: 25.2247 - val_accuracy: 0.2250 - val_categorical_crossentropy: 25.2247
# Epoch 1969/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0952 - accuracy: 0.9698 - categorical_crossentropy: 0.0952 - val_loss: 24.2835 - val_accuracy: 0.2278 - val_categorical_crossentropy: 24.2835
# Epoch 1970/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1102 - accuracy: 0.9554 - categorical_crossentropy: 0.1102 - val_loss: 24.1423 - val_accuracy: 0.2236 - val_categorical_crossentropy: 24.1423
# Epoch 1971/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0974 - accuracy: 0.9680 - categorical_crossentropy: 0.0974 - val_loss: 25.4937 - val_accuracy: 0.2208 - val_categorical_crossentropy: 25.4937
# Epoch 1972/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1049 - accuracy: 0.9644 - categorical_crossentropy: 0.1049 - val_loss: 25.4656 - val_accuracy: 0.2264 - val_categorical_crossentropy: 25.4656
# Epoch 1973/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0966 - accuracy: 0.9650 - categorical_crossentropy: 0.0966 - val_loss: 28.0077 - val_accuracy: 0.2194 - val_categorical_crossentropy: 28.0077
# Epoch 1974/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1324 - accuracy: 0.9536 - categorical_crossentropy: 0.1324 - val_loss: 27.2225 - val_accuracy: 0.2152 - val_categorical_crossentropy: 27.2225
# Epoch 1975/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0982 - accuracy: 0.9650 - categorical_crossentropy: 0.0982 - val_loss: 29.5572 - val_accuracy: 0.2138 - val_categorical_crossentropy: 29.5572
# Epoch 1976/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0852 - accuracy: 0.9735 - categorical_crossentropy: 0.0852 - val_loss: 27.7671 - val_accuracy: 0.2110 - val_categorical_crossentropy: 27.7671
# Epoch 1977/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0979 - accuracy: 0.9626 - categorical_crossentropy: 0.0979 - val_loss: 25.6751 - val_accuracy: 0.2166 - val_categorical_crossentropy: 25.6751
# Epoch 1978/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1094 - accuracy: 0.9590 - categorical_crossentropy: 0.1094 - val_loss: 27.2637 - val_accuracy: 0.2194 - val_categorical_crossentropy: 27.2637
# Epoch 1979/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0925 - accuracy: 0.9704 - categorical_crossentropy: 0.0925 - val_loss: 23.6766 - val_accuracy: 0.2152 - val_categorical_crossentropy: 23.6766
# Epoch 1980/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0994 - accuracy: 0.9668 - categorical_crossentropy: 0.0994 - val_loss: 22.2836 - val_accuracy: 0.2222 - val_categorical_crossentropy: 22.2836
# Epoch 1981/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0917 - accuracy: 0.9644 - categorical_crossentropy: 0.0917 - val_loss: 28.0079 - val_accuracy: 0.2124 - val_categorical_crossentropy: 28.0079
# Epoch 1982/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 0.1029 - accuracy: 0.9554 - categorical_crossentropy: 0.1029 - val_loss: 22.2173 - val_accuracy: 0.2194 - val_categorical_crossentropy: 22.2173
# Epoch 1983/2000
# 26/26 [==============================] - 1s 51ms/step - loss: 0.1037 - accuracy: 0.9662 - categorical_crossentropy: 0.1037 - val_loss: 20.9636 - val_accuracy: 0.2194 - val_categorical_crossentropy: 20.9636
# Epoch 1984/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1200 - accuracy: 0.9638 - categorical_crossentropy: 0.1200 - val_loss: 22.4652 - val_accuracy: 0.2194 - val_categorical_crossentropy: 22.4652
# Epoch 1985/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0963 - accuracy: 0.9698 - categorical_crossentropy: 0.0963 - val_loss: 22.5145 - val_accuracy: 0.2180 - val_categorical_crossentropy: 22.5145
# Epoch 1986/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1035 - accuracy: 0.9644 - categorical_crossentropy: 0.1035 - val_loss: 21.1727 - val_accuracy: 0.2236 - val_categorical_crossentropy: 21.1727
# Epoch 1987/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1003 - accuracy: 0.9662 - categorical_crossentropy: 0.1003 - val_loss: 24.0261 - val_accuracy: 0.2152 - val_categorical_crossentropy: 24.0261
# Epoch 1988/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1017 - accuracy: 0.9650 - categorical_crossentropy: 0.1017 - val_loss: 22.8375 - val_accuracy: 0.2194 - val_categorical_crossentropy: 22.8375
# Epoch 1989/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0935 - accuracy: 0.9662 - categorical_crossentropy: 0.0935 - val_loss: 22.3820 - val_accuracy: 0.2250 - val_categorical_crossentropy: 22.3820
# Epoch 1990/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1064 - accuracy: 0.9662 - categorical_crossentropy: 0.1064 - val_loss: 22.5976 - val_accuracy: 0.2194 - val_categorical_crossentropy: 22.5976
# Epoch 1991/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0845 - accuracy: 0.9692 - categorical_crossentropy: 0.0845 - val_loss: 22.0305 - val_accuracy: 0.2138 - val_categorical_crossentropy: 22.0305
# Epoch 1992/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1039 - accuracy: 0.9596 - categorical_crossentropy: 0.1039 - val_loss: 18.0417 - val_accuracy: 0.2138 - val_categorical_crossentropy: 18.0417
# Epoch 1993/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0993 - accuracy: 0.9614 - categorical_crossentropy: 0.0993 - val_loss: 23.3724 - val_accuracy: 0.2236 - val_categorical_crossentropy: 23.3724
# Epoch 1994/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1070 - accuracy: 0.9674 - categorical_crossentropy: 0.1070 - val_loss: 21.2640 - val_accuracy: 0.2194 - val_categorical_crossentropy: 21.2640
# Epoch 1995/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1092 - accuracy: 0.9668 - categorical_crossentropy: 0.1092 - val_loss: 21.6065 - val_accuracy: 0.2222 - val_categorical_crossentropy: 21.6065
# Epoch 1996/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 0.1050 - accuracy: 0.9632 - categorical_crossentropy: 0.1050 - val_loss: 22.5552 - val_accuracy: 0.2194 - val_categorical_crossentropy: 22.5552
# Epoch 1997/2000
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0959 - accuracy: 0.9680 - categorical_crossentropy: 0.0959 - val_loss: 22.2952 - val_accuracy: 0.2208 - val_categorical_crossentropy: 22.2952
# Epoch 1998/2000
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0958 - accuracy: 0.9650 - categorical_crossentropy: 0.0958 - val_loss: 22.4673 - val_accuracy: 0.2152 - val_categorical_crossentropy: 22.4673
# Epoch 1999/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0901 - accuracy: 0.9656 - categorical_crossentropy: 0.0901 - val_loss: 26.5202 - val_accuracy: 0.2096 - val_categorical_crossentropy: 26.5202
# Epoch 2000/2000
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0839 - accuracy: 0.9723 - categorical_crossentropy: 0.0839 - val_loss: 23.6144 - val_accuracy: 0.2152 - val_categorical_crossentropy: 23.6144

# %%
test_len = 100
train_X, test_X = X[:-100], X[-100:]
train_Y, test_Y = Y[:-100], Y[-100:]

# %%
print(train_X.shape, test_X.shape, train_Y.shape, test_Y.shape)
# Out:
# (2289, 10, 414) (100, 10, 414) (2289, 5) (100, 5)

# %%
cl_model = ConvLSTM()
history = train(cl_model, train_X, train_Y, test_X, test_Y, batch_size = 0 )
# Out:
# 2022-08-12 14:35:55.998215: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-12 14:35:56.495681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22304 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:d8:00.0, compute capability: 8.6
# 2022-08-12 14:36:04.429669: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8301
# 2022-08-12 14:36:05.965889: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 72/72 [==============================] - ETA: 0s - loss: 4.3048 - accuracy: 0.2329 - categorical_crossentropy: 4.3048WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.regularization.dropout.Dropout object at 0x7f4b64091c40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.regularization.dropout.Dropout object at 0x7f4b6402d0a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.regularization.dropout.Dropout object at 0x7f4b6402d2b0>, because it is not built.
# INFO:tensorflow:Assets written to: ./model/Resnet_LSTM/assets
# 72/72 [==============================] - 37s 388ms/step - loss: 4.3048 - accuracy: 0.2329 - categorical_crossentropy: 4.3048 - val_loss: 1.6184 - val_accuracy: 0.1900 - val_categorical_crossentropy: 1.6184

# %%
history.history['val_accuracy']
# Out:
# [0.1899999976158142]

# %%
dropout_rate = dict()
for i in range(8):
    dropout = i / 10
    print(dropout)
    model_amp = ResNet(dropout = dropout)
    history = train(model_amp, Split_X, y)
    dropout_rate[dropout] = history
# Out:
# 0.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /data_disk/home/joongho/Intelligent_Radar/gui/service_modules/training_road_lstm.ipynb 셀 19 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Baisl_gpu_server/data_disk/home/joongho/Intelligent_Radar/gui/service_modules/training_road_lstm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> print(dropout)
#       <a href='vscode-notebook-cell://ssh-remote%2Baisl_gpu_server/data_disk/home/joongho/Intelligent_Radar/gui/service_modules/training_road_lstm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> model_amp = ResNet(dropout = dropout)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Baisl_gpu_server/data_disk/home/joongho/Intelligent_Radar/gui/service_modules/training_road_lstm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> history = train(model_amp, Split_X, y)
#       <a href='vscode-notebook-cell://ssh-remote%2Baisl_gpu_server/data_disk/home/joongho/Intelligent_Radar/gui/service_modules/training_road_lstm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> dropout_rate[dropout] = history
#
# TypeError: train() missing 2 required positional arguments: 'test_X' and 'test_Y'

# %%
print(dropout_rate[0.0].history.keys())

# %%
print(np.max(dropout_rate[0.0].history['val_accuracy']))
print(np.max(dropout_rate[0.1].history['val_accuracy']))
print(np.max(dropout_rate[0.2].history['val_accuracy']))
print(np.max(dropout_rate[0.3].history['val_accuracy']))
print(np.max(dropout_rate[0.4].history['val_accuracy']))
print(np.max(dropout_rate[0.5].history['val_accuracy']))

# %%
model = ResNetLSTM()
history = train(model, X, Y)

# %%
model.summary()
